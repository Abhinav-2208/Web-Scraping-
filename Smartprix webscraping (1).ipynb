# %%
with open('smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
html
# Out:
# '<html lang="en" class="way-item-finder" style="--window-width: 1280;"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width"><title>Mobile Phones In Stock | Smartprix</title><link rel="icon" type="image/png" sizes="32x32" href="/sm-32x32.png"><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png"><meta name="theme-color" content="#4692F0"><link rel="manifest" href="/manifest.json"><meta property="fb:app_id" content="171761809591603"><link rel="canonical" href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock"><meta property="og:site_name" content="Smartprix"><meta name="twitter:site" content="@smartprix"><meta name="twitter:creator" content="@smartprix"><meta name="twitter:card" content="summary"><link rel="search" href="/smartprix_search.xml" type="application/opensearchdescription+xml" title="Smartprix Search: Find the best price"><script type="application/ld+json">{"@type":"Organization","@context":"http://schema.org/","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","sameAs":["https://www.facebook.com/smartprix","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://plus.google.com/102248368379090638322","https://www.pinterest.com/smartprixcom/","https://twitter.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://t.me/Smartprix_Deals"],"logo":"https://www.smartprix.com/smartprix.png"}</script><script type="application/ld+json">{"@type":"Website","@context":"http://schema.org/","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}</script><script type="application/ld+json">{"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Mobile Phones","item":"https://www.smartprix.com/mobiles"},{"@type":"ListItem","position":2,"name":"Mobile Phones In Stock","item":"https://www.smartprix.com/mobiles/exclude_out_of_stock-stock"}]}</script><script type="application/ld+json">{"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"Realme 11 Pro","url":"https://www.smartprix.com/mobiles/realme-11-pro-ppd1a0nt0jgz","image":["https://cdn1.smartprix.com/rx-iG0pNVWBR-w1200-h1200/G0pNVWBR.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"OnePlus Nord CE 3 Lite 5G","url":"https://www.smartprix.com/mobiles/oneplus-nord-ce-3-lite-5g-ppd11rema1vf","image":["https://cdn1.smartprix.com/rx-iAf9Lqlrt-w1200-h1200/Af9Lqlrt.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"Realme Narzo N53","url":"https://www.smartprix.com/mobiles/realme-narzo-n53-ppd1u4wnikml","image":["https://cdn1.smartprix.com/rx-iK33utT7h-w1200-h1200/K33utT7h.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Motorola Edge 40 5G","url":"https://www.smartprix.com/mobiles/motorola-edge-40-5g-ppd1u5zsytnd","image":["https://cdn1.smartprix.com/rx-iZuUTuW99-w1200-h1200/ZuUTuW99.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"Vivo T2x 5G","url":"https://www.smartprix.com/mobiles/vivo-t2x-5g-2023-ppd1jnnib7q1","image":["https://cdn1.smartprix.com/rx-iEGr7yAU6-w1200-h1200/EGr7yAU6.webp"]},{"@type":"ListItem","additionalType":"Product","position":6,"name":"Vivo T2x 5G (6GB RAM + 128GB)","url":"https://www.smartprix.com/mobiles/vivo-t2x-5g-6gb-ram-128gb-ppd1vumkzdli","image":["https://cdn1.smartprix.com/rx-idq6N7SMW-w1200-h1200/dq6N7SMW.webp"]},{"@type":"ListItem","additionalType":"Product","position":7,"name":"OnePlus Nord CE 3 Lite 5G (8GB RAM + 256GB)","url":"https://www.smartprix.com/mobiles/oneplus-nord-ce-3-lite-5g-8gb-ram-256gb-ppd13h9ngff4","image":["https://cdn1.smartprix.com/rx- ...

# %%
soup=BeautifulSoup(html,'lxml')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <html class="way-item-finder" lang="en" style="--window-width: 1280;"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><title>Mobile Phones In Stock | Smartprix</title><link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><meta content="#4692F0" name="theme-color"/><link href="/manifest.json" rel="manifest"/><meta content="171761809591603" property="fb:app_id"/><link href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock" rel="canonical"/><meta content="Smartprix" property="og:site_name"/><meta content="@smartprix" name="twitter:site"/><meta content="@smartprix" name="twitter:creator"/><meta content="summary" name="twitter:card"/><link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/><script type="application/ld+json">{"@type":"Organization","@context":"http://schema.org/","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","sameAs":["https://www.facebook.com/smartprix","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://plus.google.com/102248368379090638322","https://www.pinterest.com/smartprixcom/","https://twitter.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://t.me/Smartprix_Deals"],"logo":"https://www.smartprix.com/smartprix.png"}</script><script type="application/ld+json">{"@type":"Website","@context":"http://schema.org/","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}</script><script type="application/ld+json">{"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Mobile Phones","item":"https://www.smartprix.com/mobiles"},{"@type":"ListItem","position":2,"name":"Mobile Phones In Stock","item":"https://www.smartprix.com/mobiles/exclude_out_of_stock-stock"}]}</script><script type="application/ld+json">{"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"Realme 11 Pro","url":"https://www.smartprix.com/mobiles/realme-11-pro-ppd1a0nt0jgz","image":["https://cdn1.smartprix.com/rx-iG0pNVWBR-w1200-h1200/G0pNVWBR.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"OnePlus Nord CE 3 Lite 5G","url":"https://www.smartprix.com/mobiles/oneplus-nord-ce-3-lite-5g-ppd11rema1vf","image":["https://cdn1.smartprix.com/rx-iAf9Lqlrt-w1200-h1200/Af9Lqlrt.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"Realme Narzo N53","url":"https://www.smartprix.com/mobiles/realme-narzo-n53-ppd1u4wnikml","image":["https://cdn1.smartprix.com/rx-iK33utT7h-w1200-h1200/K33utT7h.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Motorola Edge 40 5G","url":"https://www.smartprix.com/mobiles/motorola-edge-40-5g-ppd1u5zsytnd","image":["https://cdn1.smartprix.com/rx-iZuUTuW99-w1200-h1200/ZuUTuW99.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"Vivo T2x 5G","url":"https://www.smartprix.com/mobiles/vivo-t2x-5g-2023-ppd1jnnib7q1","image":["https://cdn1.smartprix.com/rx-iEGr7yAU6-w1200-h1200/EGr7yAU6.webp"]},{"@type":"ListItem","additionalType":"Product","position":6,"name":"Vivo T2x 5G (6GB RAM + 128GB)","url":"https://www.smartprix.com/mobiles/vivo-t2x-5g-6gb-ram-128gb-ppd1vumkzdli","image":["https://cdn1.smartprix.com/rx-idq6N7SMW-w1200-h1200/dq6N7SMW.webp"]},{"@type":"ListItem","additionalType":"Product","position":7,"name":"OnePlus Nord CE 3 Lite 5G (8GB RAM + 256GB)","url":"https://www.smartprix.com/mobiles/oneplus-nord-ce-3-lite-5g-8gb-ram-256gb-ppd13h9ngff4 ...

# %%
len(soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}))
# Out:
# 140

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
for i in containers:
    print(i.find('h2').text)
    print(i.find('span',{'class':'price'}).text)
    try:
        print(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        print(np.nan)
# Out:
# OnePlus Nord CE 3 Lite 5G
# ₹19,999
# 85
# Realme Narzo N53
# ₹8,999
# 70
# Motorola Edge 40 5G
# ₹29,999
# 87
# Vivo T2x 5G
# ₹17,999
# 75
# Vivo T2x 5G (6GB RAM + 128GB)
# ₹13,999
# 77
# OnePlus Nord CE 3 Lite 5G (8GB RAM + 256GB)
# ₹21,999
# 86
# Realme Narzo N53 (6GB RAM + 128GB)
# ₹10,999
# 74
# Vivo V27
# ₹32,999
# 85
# Samsung Galaxy M14 (6GB RAM + 128GB)
# ₹14,979
# 80
# OnePlus 11R 5G
# ₹39,399
# 85
# Realme C55 (8GB RAM + 128GB)
# ₹13,799
# 79
# Xiaomi Redmi A2
# ₹6,299
# 61
# Samsung Galaxy S21 FE 5G
# ₹34,945
# 87
# Motorola Moto G32 (8GB RAM + 128GB)
# ₹11,999
# 81
# Samsung Galaxy S20 FE 5G
# ₹26,891
# 88
# Realme 10 Pro Plus
# ₹23,499
# 82
# Vivo V27 Pro
# ₹37,999
# 84
# Vivo T2 5G
# ₹18,999
# 79
# iQOO Z7 5G
# ₹18,999
# 82
# Apple iPhone 13
# ₹61,999
# 79
# Xiaomi Redmi Note 12 Pro 5G
# ₹23,820
# 79
# Motorola Moto G73
# ₹16,999
# 84
# OnePlus 11 5G
# ₹54,899
# 89
# Oppo Reno 8T
# ₹29,999
# 86
# Vivo T2x 5G (8GB RAM + 128GB)
# ₹20,999
# 80
# OPPO F23
# ₹23,729
# 84
# Samsung Galaxy S23 Ultra 5G
# ₹1,24,999
# nan
# Motorola Moto G42
# ₹9,999
# 78
# OnePlus Nord CE 2 Lite 5G
# ₹18,881
# 81
# Apple iPhone 14 Pro Max
# ₹1,27,999
# 85
# Apple iPhone 14
# ₹67,999
# 81
# Poco F5
# ₹29,999
# 84
# Xiaomi Redmi Note 12
# ₹16,999
# 76
# Realme Narzo N55
# ₹10,999
# 73
# Realme GT Neo 3T
# ₹22,999
# 79
# Xiaomi Redmi A2 (4GB RAM + 64GB)
# ₹7,999
# 66
# Realme 10 Pro
# ₹18,999
# 82
# Samsung Galaxy A34 5G
# ₹28,000
# 84
# Motorola Moto G62 5G
# ₹15,499
# 81
# Samsung Galaxy A54 5G
# ₹35,990
# 88
# Nothing Phone 1
# ₹29,999
# 85
# Samsung Galaxy A34 5G
# ₹30,200
# 84
# Samsung Galaxy A54 5G
# ₹35,990
# 88
# OnePlus 10R 5G
# ₹30,799
# 84
# Samsung Galaxy S23 5G
# ₹69,999
# 88
# Samsung Galaxy M14
# ₹14,160
# 78
# Xiaomi Redmi Note 10T 5G (6GB RAM +128GB)
# ₹13,719
# 79
# Samsung Galaxy F23 5G (6GB RAM + 128GB)
# ₹16,999
# 80
# Realme C55
# ₹10,999
# 73
# iQOO Z7 5G (8GB RAM + 128GB)
# ₹19,999
# 84
# Samsung Galaxy M33 5G
# ₹16,323
# 81
# Google Pixel 7A
# ₹43,999
# 86
# Samsung Galaxy S22 Ultra 5G
# ₹87,099
# nan
# Xiaomi Redmi 12C
# ₹8,799
# 70
# OnePlus 11R (16GB RAM + 256GB)
# ₹44,429
# 87
# Motorola Moto G13
# ₹9,999
# 75
# Samsung Galaxy F04
# ₹8,299
# 68
# Xiaomi Redmi 11 Prime 5G
# ₹12,800
# 74
# Tecno Spark 10 Pro
# ₹12,499
# 80
# Realme 10
# ₹11,999
# 74
# Samsung Galaxy M53 5G
# ₹23,290
# 85
# Apple iPhone 11
# ₹40,999
# 73
# Poco C55
# ₹7,999
# 71
# Realme Narzo N55 (6GB RAM + 128GB)
# ₹12,999
# 76
# Vivo V27 (12GB RAM + 256GB)
# ₹36,999
# 86
# Vivo Y100
# ₹23,999
# 83
# Xiaomi Redmi Note 12 Pro Plus
# ₹29,350
# 86
# Infinix Hot 30i
# ₹9,299
# 76
# OnePlus 10 Pro 5G
# ₹47,999
# 89
# Samsung Galaxy F14 5G
# ₹14,490
# 69
# Vivo Y56
# ₹19,790
# 83
# Samsung Galaxy A14 5G (6GB RAM + 128GB)
# ₹18,999
# 79
# Realme 10 Pro (8GB RAM + 128GB)
# ₹19,999
# 84
# Poco C51
# ₹6,999
# 66
# Xiaomi Redmi K50i 5G
# ₹20,790
# 82
# Motorola Edge 30 Ultra
# ₹44,999
# nan
# Xiaomi Redmi Note 10S
# ₹10,779
# 78
# Apple iPhone 14 Plus
# ₹78,999
# 82
# iQOO Neo 6 5G
# ₹24,999
# 82
# Poco X5 Pro
# ₹22,999
# 81
# Poco M5
# ₹8,999
# 74
# Samsung Galaxy A73 5G
# ₹37,999
# nan
# Vivo V27 Pro (12GB RAM + 256GB)
# ₹42,999
# 86
# Realme 10 Pro Plus (8GB RAM + 128GB)
# ₹24,499
# 84
# Realme C55 (6GB RAM + 64GB)
# ₹11,899
# 75
# Oppo A78
# ₹18,248
# 79
# Xiaomi Redmi 11 Prime
# ₹9,999
# 74
# Realme 9i 5G
# ₹14,699
# 75
# iQOO Neo 7 5G
# ₹27,999
# 82
# Poco X5
# ₹15,999
# 81
# Samsung Galaxy M53 5G (8GB RAM + 128GB)
# ₹24,232
# 87
# Apple iPhone 14 Pro
# ₹1,19,999
# 84
# OnePlus 11 (16GB RAM + 256GB)
# ₹61,449
# nan
# Vivo X90 5G
# ₹59,999
# 89
# Samsung Galaxy M33 5G (8GB RAM + 128GB)
# ₹17,572
# 84
# Motorola Edge 30 5G
# ₹24,999
# 83
# Vivo Y22 (6GB RAM + 128GB)
# ₹16,499
# 75
# Vivo Y35
# ₹17,499
# 80
# iQOO Z6 Lite (6GB RAM + 128GB)
# ₹13,999
# 79
# Samsung Galaxy S22 5G
# ₹49,399
# 86
# Apple iPhone 12
# ₹53,999
# 74
# Tecno Spark 10 5G (8GB RAM + 256GB)
# ₹14,999
# 80
# Vivo T2 5G (8GB RAM + 128GB)
# ₹20,999
# 82
# iKall Z19 Pro
# ₹7,989
# 60
# Poco M4 5G
# ₹11,999
# 75
# Vivo Y22
# ₹14,499
# 72
# Apple iPhone 13 Pro
# ₹1,19,900
# 83
# iQOO Z6 Lite 5G
# ₹14,479
# 75
# Realme C33
# ₹8,699
# 64
# Vivo V25 5G
# ₹25,930
# 83
# Nokia 106 4G
# ₹2,700
# nan
# Motorola Moto E13 (4GB RAM + 64GB)
# ₹7,499
# 67
# Motorola Moto G82 5G
# ₹19,999
# 83
# Samsung Galaxy F14 5G (6GB RAM + 128GB)
# ₹15,490
# 72
# Motorola Edge 30 Pro 5G
# ₹34,999
# 89
# Google Pixel 6 Pro
# ₹45,499
# 89
# OPPO Reno8 5G
# ₹29,999
# 83
# Lava Agni 5G
# ₹15,990
# 84
# OPPO A17
# ₹12,190
# 72
# Samsung Galaxy F13
# ₹10,999
# 74
# Realme GT Neo 3 5G
# ₹26,785
# 83
# Xiaomi Redmi A1
# ₹5,699
# nan
# Vivo V25 Pro 5G
# ₹31,299
# 84
# Xiaomi Redmi Note 11
# ₹12,999
# 76
# Xiaomi Redmi Note 12 (8GB RAM + 256GB)
# ₹20,999
# 82
# Vivo Y16 (4GB RAM + 128GB)
# ₹12,990
# 69
# Motorola Moto G62 (8GB RAM + 128GB)
# ₹16,499
# 84
# Samsung Galaxy A23 5G
# ₹21,600
# 79
# Vivo V23 5G (12GB RAM + 256GB)
# ₹27,340
# 86
# Realme 10 (8GB RAM + 128GB)
# ₹14,999
# 79
# Motorola Moto G32
# ₹10,999
# 75
# Google Pixel 6A
# ₹28,999
# 71
# Xiaomi Redmi Note 12 4G
# ₹14,999
# 79
# Motorola Edge 30 Ultra (12GB RAM + 256GB)
# ₹49,999
# nan
# Poco M4 5G (6GB RAM + 128GB)
# ₹13,999
# 79
# Vivo Y16
# ₹9,999
# 65
# Infinix Note 12 Pro 5G
# ₹15,999
# 84
# Samsung Galaxy A73 5G (8GB RAM + 256GB)
# ₹39,270
# nan
# Motorola Moto G60
# ₹14,999
# 84
# Xiaomi Redmi 12C (6GB RAM + 128GB)
# ₹10,790
# 74

# %%
name=[]
price=[]
specs=[]

for i in containers:
    name.append(i.find('h2').text)
    price.append(i.find('span',{'class':'price'}).text)
    try:
        specs.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        specs.append(np.nan)

# %%
len(name)
# Out:
# 140

# %%
len(price)
# Out:
# 140

# %%
len(specs)
# Out:
# 140

# %%
df = pd.DataFrame({
    'model':name,
    'price':price,
    'rating':specs
})

# %%
df
# Out:
#                                        model    price rating
# 0                  OnePlus Nord CE 3 Lite 5G  ₹19,999     85
# 1                           Realme Narzo N53   ₹8,999     70
# 2                        Motorola Edge 40 5G  ₹29,999     87
# 3                                Vivo T2x 5G  ₹17,999     75
# 4              Vivo T2x 5G (6GB RAM + 128GB)  ₹13,999     77
# ..                                       ...      ...    ...
# 135                                 Vivo Y16   ₹9,999     65
# 136                   Infinix Note 12 Pro 5G  ₹15,999     84
# 137  Samsung Galaxy A73 5G (8GB RAM + 256GB)  ₹39,270    NaN
# 138                        Motorola Moto G60  ₹14,999     84
# 139       Xiaomi Redmi 12C (6GB RAM + 128GB)  ₹10,790     74
#
# [140 rows x 3 columns]

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                                        model    price rating  \
# 0                  OnePlus Nord CE 3 Lite 5G  ₹19,999     85
# 1                           Realme Narzo N53   ₹8,999     70
# 2                        Motorola Edge 40 5G  ₹29,999     87
# 3                                Vivo T2x 5G  ₹17,999     75
# 4              Vivo T2x 5G (6GB RAM + 128GB)  ₹13,999     77
# ..                                       ...      ...    ...
# 135                                 Vivo Y16   ₹9,999     65
# 136                   Infinix Note 12 Pro 5G  ₹15,999     84
# 137  Samsung Galaxy A73 5G (8GB RAM + 256GB)  ₹39,270    NaN
# 138                        Motorola Moto G60  ₹14,999     84
# 139       Xiaomi Redmi 12C (6GB RAM + 128GB)  ₹10,790     74
#
#                                          sim  \
# 0         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1             Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 2    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 3         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ..                                       ...
# 135           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 136       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 137  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 138      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 139           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                            processor  \
# 0    Snapdragon 695 5G, Octa Core, 2.2 GHz Processor
# 1          Unisoc T612, Octa Core, 1.8 GHz Processor
# 2       Dimensity 8020, Octa Core, 2.6 GHz Processor
# 3       Dimensity 6020, Octa Core, 2.2 GHz Processor
# 4       Dimensity 6020, Octa Core, 2.2 GHz Processor
# ..                                               ...
# 135          Helio P35, Octa Core, 2.3 GHz Processor
# 136   Dimensity 810 5G, Octa Core, 2.4 GHz Processor
# 137    Snapdragon 778G, Octa Core, 2.4 GHz Processor
# 138   Snapdragon  732G, Octa Core, 2.3 GHz Processor
# 139           Helio  G85, Octa Core, 2 GHz Processor
#
#                           ram                                  battery  \
# 0    8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 67W Fast Charging
# 1     4 GB RAM, 64 GB inbuilt  5000 mAh Battery with 33W Fast Charging
# 2    8 GB RAM, 256 GB inbuilt  4400 mAh Battery with 68W Fast Charging
# 3    4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 4    6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# ..                        ...                                      ...
# 135   3 GB RAM, 32 GB inbuilt  5000 mAh Battery with 10W Fast Charging
# 136  8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 33W Fast Charging
# 137  8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 25W Fast Charging
# 138  6 GB RAM, 128 GB inbuilt  6000 mAh Battery with 20W Fast Charging
# 139  6 GB RAM, 128 GB inbuilt                         5000 mAh Battery
#
#                                                display  \
# 0    6.72 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1    6.74 inches, 720 x 1600 px, 90 Hz Display with...
# 2          6.55 inches, 1080 x 2400 px, 144 Hz Display
# 3    6.58 inches, 1080 x 2408 px Display with Water...
# 4    6.58 inches, 1080 x 2408 px Display with Water...
# ..                                                 ...
# 135  6.51 inches, 720 x 1600 px Display with Water ...
# 136  6.7 inches, 1080 x 2400 px Display with Punch ...
# 137  6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 138  6.78 inches, 1080 x 2460 px, 120 Hz Display wi...
# 139  6.71 inches, 720 x 1650 px Display with Water ...
#
#                                                 camera  \
# 0    108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front...
# 1    50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 2         50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 3           50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 4           50 MP + 2 MP Dual Rear & 8 MP Front Camera
# ..                                                 ...
# 135         13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 136  108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front...
# 137              108 MP Quad Rear & 32 MP Front Camera
# 138  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 139  50 MP + Depth Sensor Dual Rear & 5 MP Front Ca...
#
#                                  card           os
# 0     Memory Card (Hybrid), upto 1 TB  Android v13
# 1    Memory Card Supported, upto 2 TB  Android v13
# 2                         Android v13    Bluetooth
# 3     Memory Card (Hybrid), upto 1 TB  Android v13
# 4     Memory Card (Hybrid), upto 1 TB  Android v13
# ..                                ...          ...
# 135             Memory Card Supported  Android v12
# 136  Memory Card Supported, upto 2 TB  Android v12
# 137   Memory Card (Hybrid), upto 1 TB  Android v12
# 138   Memory Card (Hybrid), upto 1 TB  Android v11
# 139  Memory Card Supported, upto 1 TB  Android v12
#
# [140 rows x 11 columns]

# %%
df.to_csv('smartphones.csv',index=False)

# %%
df.head()
# Out:
#                            model    price rating  \
# 0      OnePlus Nord CE 3 Lite 5G  ₹19,999     85
# 1               Realme Narzo N53   ₹8,999     70
# 2            Motorola Edge 40 5G  ₹29,999     87
# 3                    Vivo T2x 5G  ₹17,999     75
# 4  Vivo T2x 5G (6GB RAM + 128GB)  ₹13,999     77
#
#                                        sim  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                       ram  \
# 0  Snapdragon 695 5G, Octa Core, 2.2 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1        Unisoc T612, Octa Core, 1.8 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2     Dimensity 8020, Octa Core, 2.6 GHz Processor  8 GB RAM, 256 GB inbuilt
# 3     Dimensity 6020, Octa Core, 2.2 GHz Processor  4 GB RAM, 128 GB inbuilt
# 4     Dimensity 6020, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 67W Fast Charging
# 1  5000 mAh Battery with 33W Fast Charging
# 2  4400 mAh Battery with 68W Fast Charging
# 3  5000 mAh Battery with 18W Fast Charging
# 4  5000 mAh Battery with 18W Fast Charging
#
#                                              display  \
# 0  6.72 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1  6.74 inches, 720 x 1600 px, 90 Hz Display with...
# 2        6.55 inches, 1080 x 2400 px, 144 Hz Display
# 3  6.58 inches, 1080 x 2408 px Display with Water...
# 4  6.58 inches, 1080 x 2408 px Display with Water...
#
#                                               camera  \
# 0  108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front...
# 1  50 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 2       50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 3         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 4         50 MP + 2 MP Dual Rear & 8 MP Front Camera
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v13
# 1  Memory Card Supported, upto 2 TB  Android v13
# 2                       Android v13    Bluetooth
# 3   Memory Card (Hybrid), upto 1 TB  Android v13
# 4   Memory Card (Hybrid), upto 1 TB  Android v13

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df.shape
# Out:
# (140, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      140 non-null    object
#  1   price      140 non-null    object
#  2   rating     131 non-null    object
#  3   sim        140 non-null    object
#  4   processor  140 non-null    object
#  5   ram        140 non-null    object
#  6   battery    140 non-null    object
#  7   display    140 non-null    object
#  8   camera     140 non-null    object
#  9   card       140 non-null    object
#  10  os         140 non-null    object
# dtypes: object(11)
# memory usage: 12.2+ KB

# %%
df.isnull().sum()
# Out:
# model        0
# price        0
# rating       9
# sim          0
# processor    0
# ram          0
# battery      0
# display      0
# camera       0
# card         0
# os           0
# dtype: int64
